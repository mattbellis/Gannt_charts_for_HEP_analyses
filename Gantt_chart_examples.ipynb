# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/mattbellis/Gantt_charts_for_HEP_analyses/blob/master/Gantt_chart_examples.ipynb)

# %% [markdown]
# # Gantt chart examples in python
#
# # Make sure you make a copy of this notebook before you start editing!!!!
#
# *If you just want to play around with this code, go to "File --> Open in playground". Changes there will not be saved until you "File --> Save to Drive"*
#
# ***Hit Ctrl-Enter to execute any of the cells below***

# %%
###### THIS CELL ONLY NEEDS TO BE RUN ONCE ####################
######
###### BUT IT DOES NEED TO BE RUN!         ####################

import matplotlib.pylab as plt

# Check to see if the git repo is there. If not, then clone it
# !if [ ! -e python-Gantt-chart ]; then git  clone https://github.com/mattbellis/python-Gantt-chart.git; fi

# Pull the latest changes  
# !cd python-Gantt-chart; git pull

# Add the repo directiory to our path and import the module
import sys
sys.path.insert(0,'./python-Gantt-chart')
import gantt_chart as gc

from collections import OrderedDict
# Out:
# Cloning into 'python-Gantt-chart'...
# remote: Counting objects: 57, done.
# remote: Total 57 (delta 0), reused 0 (delta 0), pack-reused 57
# Unpacking objects: 100% (57/57), done.
# Already up-to-date.

# %% [markdown]
# # EXAMPLE 1 - CMS Approval schedule
#
# Derived from [CMS DAS Writers Pub discussion by Sara Eno (UMD)](https://twiki.cern.ch/twiki/pub/CMS/Internal/Publications/Approval_steps.pdf)
#
# [Timeline of a paper review process](https://twiki.cern.ch/twiki/pub/CMS/Internal/Publications/Approval_steps.pdf)

# %%
activities = OrderedDict()

activities["analysis"] = {"name":"Analysis Record Created in CADI", "start":"1/1/2018", "duration":10, "type_of_work":"PAG conveners"}
activities["discuss"] = {"name":"Discuss Analysis Regularly", "start":"analysis", "duration":90, "type_of_work":"authors"}
activities["nonstand"] = {"name":"Get Non-Standard Tools Approved", "start":"analysis", "duration":30, "type_of_work":"authors"}
activities["target"] = {"name":"Update Pre-Approval Target Dates", "start":"nonstand", "duration":10, "type_of_work":"PAG conveners"}
activities["arc"] = {"name":"Request ARC Formation", "start":"nonstand", "duration":10, "type_of_work":"PAG conveners"}
activities["decide"] = {"name":"Decide to Submit for Pre-Approval", "start":"arc", "duration":10, "type_of_work":"wgconveners"}
activities["submit"] = {"name":"Submit PAS and AN-NOTE", "start":"decide", "duration":10, "type_of_work":"authors"}                       
activities["announce"] = {"name":"Announce Pre-Approval Meeting", "start":"decide", "duration":10, "type_of_work":"PAG conveners"}
activities["read"] = {"name":"General Reading Week", "start":"announce", "duration":12, "type_of_work":"authors"}
activities["meet"] = {"name":"Pre-Approval Meeting", "start":"read", "duration":20, "type_of_work":"authors"}
activities["new"] = {"name":"Submit New PAS and AN-NOTE", "start":"meet", "duration":10, "type_of_work":"authors"}
activities["flag"] = {"name":"Set Flag in CADI", "start":"meet", "duration":10, "type_of_work":"PAG conveners"}
activities["newsch"]= {"name":"Discuss Analysis Schedule", "start":"flag", "duration":30, "type_of_work":"authors"}
activities["review"] = {"name":"ARC Review", "start":"newsch", "duration":25, "type_of_work":"authors"}
activities["pas"] = {"name":"Submit Updated PAS and AN-NOTE", "start":"review", "duration":10, "type_of_work":"authors"}
activities["app"] = {"name":"Decide to Submit for Approval", "start":"pas", "duration":20, "type_of_work":"authors"}
activities["froz"] = {"name":"Documentation Frozen", "start":"app", "duration":30, "type_of_work":"authors"}
activities["ann"] = {"name":"Approval Announcement", "start":"froz", "duration":10, "type_of_work":"authors"}
activities["cms"] = {"name":"CMS Members Read", "start":"ann", "duration":25, "type_of_work":"authors"}
activities["approv"] = {"name":"Approval Meeting", "start":"cms", "duration":30, "type_of_work":"authors"}
activities["upd"] = {"name":"Submit Final PAS and AN-NOTE", "start":"approv", "duration":10, "type_of_work":"authors"}
activities["check"] = {"name":"Check Author Implemented Comments", "start":"upd", "duration":30, "type_of_work":"authors"}
activities["cadi"] = {"name":"Set Flag in CADI", "start":"check", "duration":10, "type_of_work":"PAG conveners"}
activities["qual"] = {"name":"Check Plot Qualities", "start":"upd", "duration":30, "type_of_work":"authors"}
activities["public"] = {"name":"Make Plots Public", "start":"qual", "duration":10, "type_of_work":"PAG conveners"}
activities["paspub"] = {"name":"Make PAS Public", "start":"qual", "duration":10, "type_of_work":"authors"}



colors = {"PAG conveners":"r", "wgconveners":"b", "authors":"g"}

plt.figure(figsize=(15,8))
ax2 = gc.gantt_chart(activities,colors)

# %% [markdown]
# # EXAMPLE 2 - Wedding planning

# %%
activities = OrderedDict()

activities["date"] = {"name":"Choose Date", "start":"1/1/2018", "duration":10, "type_of_work":"logistics"}
activities["photo"] = {"name":"Book Photographer", "start":"1/1/2018", "duration":10, "type_of_work":"logistics"}
activities["bridpar"] = {"name":"Choose Bridal Party", "start":"1/1/2018", "duration":20, "type_of_work":"logistics"}
activities["ven"] = {"name":"Book Venue", "start":"1/1/2018", "duration":10, "type_of_work":"logistics"}
activities["decor"] = {"name":"Plan Decor", "start":"ven", "duration":30, "type_of_work":"accessories"}
activities["flor"] = {"name":"Florist Appt", "start":"2/1/2018", "duration":10, "type_of_work":"accessories"}
activities["cat"] = {"name":"Book Caterer", "start":"ven", "duration":10, "type_of_work":"accessories"}
activities["guest"] = {"name":"Guest List", "start":"3/1/2018", "duration":20, "type_of_work":"logistics"}
activities["reg"] = {"name":"Gift Registry", "start":"guest", "duration":10, "type_of_work":"logistics"}
activities["off"] = {"name":"Get Officiant", "start":"3/1/2018", "duration":10, "type_of_work":"logistics"}
activities["mus"] = {"name":"Choose Music", "start":"3/1/2018", "duration":20, "type_of_work":"accessories"}
activities["gown"] = {"name":"Gown Order & Alter", "start":"4/1/2018", "duration":30, "type_of_work":"clothes"}
activities["hairacc"] = {"name":"Order Hair Acc", "start":"gown", "duration":10, "type_of_work":"accessories"}
activities["jewelry"] = {"name":"Order Jewelry", "start":"gown", "duration":10, "type_of_work":"accessories"}
activities["honey"] = {"name":"Plan&Book Honeymoon", "start":"5/1/2018", "duration":30, "type_of_work":"logistics"}
activities["inv"] = {"name":"Print Wedding Invitations", "start":"7/1/2018", "duration":20, "type_of_work":"accessories"}
activities["run"] = {"name":"Hair&Makeup Run Through", "start":"hairacc", "duration":20, "type_of_work":"accessories"}
activities["groom"] = {"name":"Groom Attire", "start":"9/1/2018", "duration":30, "type_of_work":"clothes"}
activities["save"] = {"name":"Save the Date Cards", "start":"9/1/2018", "duration":10, "type_of_work":"accessories"}
activities["send"] = {"name":"Send Invitations", "start":"11/1/2018", "duration":10, "type_of_work":"accessories"}
activities["seat"] = {"name":"Finalize Seating Chart", "start":"12/15/2018", "duration":20, "type_of_work":"logistics"}
activities["dayof"] = {"name":"Create Wedding Day Schedule", "start":"12/15/2018", "duration":30, "type_of_work":"logistics"}

colors = {"clothes":"r", 
           "accessories":"b",
           "logistics":"g"}

plt.figure(figsize=(20,8))
ax2 = gc.gantt_chart(activities,colors)

# %% [markdown]
# # Your CMS analysis!!!!
#
# Show us what your analysis looks like! Or what you think your analysis *will* look like!

# %%
# This is obviously not how an analysis looks, but it should be wrong enough
# that you want to edit it and fix it.  :)

activities = OrderedDict()

activities["genmc"] = {"name":"Generate MC", "start":"12/1/2017", "duration":60, "type_of_work":"grid"}
activities["pas"] = {"name":"Write Physics Analysis Note", "start":"2/1/2018", "duration":90, "type_of_work":"writing"}
activities["opt"] = {"name":"Optimize", "start":"genmc", "duration":20, "type_of_work":"code"}
activities["test"] = {"name":"THIS", "start":"4/1/2018", 'end':"7/1/2019", "duration":20, "type_of_work":"code"}
activities["test1"] = {"name":"NEW", "start":"5/12/2018", 'end':"6/19/2019", "duration":60, "type_of_work":"writing"}

colors = {"grid":"r", 
           "writing":"b",
           "code":"g"}

plt.figure(figsize=(15,8))
ax2 = gc.gantt_chart(activities,colors)

plt.xticks(fontsize=18, rotation=330);

# %%
activities = OrderedDict()

activities["mont"] = {"name":"Create Monte Carlo", "start":"1/1/2018", "duration":10, "type_of_work":"montecarlo"}
activities["sim"] = {"name":"Run Monte Carlo Simulation", "start":"mont", "duration":10, "type_of_work":"montecarlo"}
activities["plot"] = {"name":"Plot Simulation Results", "start":"sim", "duration":20, "type_of_work":"montecarlo"}
activities['realdata'] = {"name":"Run Real Data", "start":"plot", "duration":10, "type_of_work":"realdata"}
activities["plotreal"] = {"name":"Plot Real Data Results", "start":"realdata", "duration":20, "type_of_work":"realdata"}
activities["compare"] = {"name":"Compare Monte Carlo Results to Real Data", "start":"plotreal", "duration":10, "type_of_work":"realdata"}
activities["analyze"] = {"name":"Analyze Results and Draw Conclusions", "start":"compare", "duration":10, "type_of_work":"analysis"}
activities["repeat"] = {"name":"Repeat Above Steps as Necessary", "start":"analyze", "duration":10, "type_of_work":"analysis"}
activities["public"] = {"name":"Begin Publication Procedure", "start":"repeat", "duration":10, "type_of_work":"analysis"}




colors = {"montecarlo":"r", 
           "realdata":"b",
           "analysis":"g"}

plt.figure(figsize=(20,8))
ax2 = gc.gantt_chart(activities,colors)
